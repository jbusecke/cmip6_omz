# %% [markdown]
# # Quick: Produce maps of age/o2/epc changes in the Pacific
#
# ## TODO:
# - MMM maps + individual maps of slope in o2/epc/age
#     - 100-1000
#     - 100-3000
#     - 100-Full
#
# - Confirm for SI, that the sign amplitude is similar when only taking MMM over models that have all variables

# %%
# %load_ext autoreload
# %autoreload 2

import cf_xarray
import intake
import xarray as xr
import numpy as np

from cmip6_preprocessing.utils import cmip6_dataset_id
from cmip6_preprocessing.preprocessing import combined_preprocessing
from cmip6_preprocessing.postprocessing import (
    match_metrics,
    interpolate_grid_label,
    merge_variables,
    concat_experiments,
)

from cmip6_preprocessing.drift_removal import match_and_remove_trend
from fastprogress.fastprogress import progress_bar

from xhistogram.xarray import histogram

from cmip6_omz.utils import cmip6_collection, o2_models
from cmip6_omz.upstream_stash import (
    pick_first_member,
    construct_static_dz,
    concat_time,
    zarr_exists,
    pick_first_member,
)
from cmip6_omz.units import convert_mol_m3_mymol_kg

from xarrayutils.file_handling import maybe_create_folder

### needs cleaning
from cmip6_omz.omz_tools import omz_thickness_efficient
import matplotlib.pyplot as plt
from cmip6_omz.upstream_stash import append_write_zarr

from dask.diagnostics import ProgressBar

from busecke_etal_2021_aguadv.utils import fail_age

# %% [markdown]
# ## Start the processing

# %%
ofolder = maybe_create_folder('/projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3')
# Out:
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/xarrayutils/file_handling.py:118: UserWarning: Folder /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3 does already exist.
#   warnings.warn(f"Folder {path} does already exist.", UserWarning)

# %%
o2_models()
# Out:
# ['ACCESS-ESM1-5',
#  'CESM2',
#  'CESM2-WACCM',
#  'CMCC-ESM2',
#  'CNRM-ESM2-1',
#  'CanESM5',
#  'CanESM5-CanOE',
#  'EC-Earth3-CC',
#  'GFDL-CM4',
#  'GFDL-ESM4',
#  'IPSL-CM5A2-INCA',
#  'IPSL-CM6A-LR',
#  'KIOST-ESM',
#  'MIROC-ES2L',
#  'MPI-ESM-1-2-HAM',
#  'MPI-ESM1-2-HR',
#  'MPI-ESM1-2-LR',
#  'MRI-ESM2-0',
#  'NorESM2-LM',
#  'NorESM2-MM',
#  'UKESM1-0-LL']

# %%
# # these are already there
# array(['ACCESS-ESM1-5', 'CanESM5', 'GFDL-CM4', 'IPSL-CM6A-LR',
#        'MIROC-ES2L'], dtype='<U13')

# %%
col = cmip6_collection(zarr=False)
kwargs = dict(
    aggregate=False,
    zarr_kwargs={"decode_times": True, "use_cftime": True, "consolidated": True},
    cdf_kwargs={"decode_times": True, "use_cftime": True, "chunks": {"time": 1}},
    preprocess=combined_preprocessing,
)

variable_ids = ['thetao', 'so', 'o2']# "o2" #"epc100","agessc"
# variable_ids = ["o2", "agessc"]
metric_variable_ids = ["thkcello", "areacello"]  # "mlotst"

# models = o2_models()
models = [
        'UKESM1-0-LL',
        'IPSL-CM6A-LR', # all member done
        'MIROC-ES2L', # all member done
        'ACCESS-ESM1-5',  # all member done
        'CanESM5', # all member done
        'MPI-ESM1-2-LR',#all member done
        'CanESM5-CanOE',#all member done
        'CNRM-ESM2-1', #all member done
    
#     'MRI-ESM2-0', # all member done
#    'MPI-ESM1-2-HR', # all member done
#     'NorESM2-LM',#all member done
#     'NorESM2-MM',#all member done     
#     "GFDL-CM4",# all member done
#     "GFDL-ESM4",#all member done
]

cat = col.search(
    source_id=models,
    grid_label=["gr", "gn"],
    experiment_id=["historical", "ssp585"],
    table_id=["Omon"],
    variable_id=variable_ids,
)
ds_dict = cat.to_dataset_dict(**kwargs)

# make a separate metric dict to catch all possible metrics!
cat_metrics = col.search(source_id=models, variable_id=metric_variable_ids)
ds_metric_dict = cat_metrics.to_dataset_dict(**kwargs)

# combine in time (only needed for netcdf collection)
ds_dict = concat_time(ds_dict)
ds_metric_dict = concat_time(ds_metric_dict)

# Brute Force add the GFDL age
patch_source_ids = [si for si in models if 'GFDL' in si]

if 'agessc' in variable_ids and len(patch_source_ids)>0:
    # TODO: Make this nicer with the original netcdf files (not tonight though)
    col_gfdl = cmip6_collection(zarr=True)
    # BUG: There is something weird going on in the reading process here
    # Just drop everything that is not GFDL
    df = col_gfdl.df
    df = df.iloc[ ['GFDL' in i for i in df['source_id']], :]
    df = df.iloc[ ['agessc' in i for i in df['variable_id']], :]
    
    col_gfdl.df = df
    cat_gfdl = col_gfdl.search(
        source_id=patch_source_ids,
        variable_id=["agessc"],
        experiment_id=["historical", "ssp585"],
    )

    ddict_gfdl_age = cat_gfdl.to_dataset_dict(**kwargs)
    ddict_gfdl_age = {k:ds for k, ds in ddict_gfdl_age.items()}
    ds_dict.update(ddict_gfdl_age)
    
    chunk_dict = {'lev':5}

    # rechunk the GFDL models in depth
    def maybe_rechunk(ds):
        subset_chunk_dict = {k:v for k,v in chunk_dict.items() if k in ds.dims}
        if ds.source_id in ["GFDL-CM4","GFDL-ESM4"] and len(subset_chunk_dict)>0:
            ds = ds.chunk(subset_chunk_dict)
        return ds
    ds_dict = {k:maybe_rechunk(ds) for k,ds in ds_dict.items()}
# Out:
# Dataframe size before picking latest version: 2280
# Getting latest version...
#
# Dataframe size after picking latest version: 2258
#
# Done....
#
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.dcpp_init_year.version.time_range.path'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6508' class='' max='6508' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6508/6508 1:40:12<00:00]
#     </div>
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r25i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r7i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r4i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r21i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r19i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r22i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r25i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r29i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r10i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1000p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r23i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r28i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r18i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r28i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r26i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r27i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r6i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r9i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r21i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r14i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r6i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r3i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r23i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r5i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r2i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r20i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r7i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r17i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r7i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r19i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r8i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r4i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r23i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r6i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r9i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r5i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r2i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r15i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r21i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r3i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r9i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r4i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r26i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r24i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1000p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r10i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r30i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r8i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r9i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r11i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r9i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r22i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r18i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r12i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r17i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r16i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r14i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1000p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r22i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r8i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r27i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r1i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r7i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r17i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r24i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r7i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r14i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r3i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r16i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r6i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r4i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r6i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r5i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r8i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r5i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r13i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r7i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r4i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r12i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r12i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r10i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r26i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r27i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r2i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r20i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r8i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r15i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r25i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r5i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r30i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r18i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r11i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r4i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r20i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r5i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r8i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r11i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r19i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r9i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r13i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r30i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r24i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r29i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r1i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r1i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r10i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r1i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r15i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r2i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r13i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r29i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r6i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r28i1p1f2.Omon.gn.none.so: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: ScenarioMIP.MIROC.MIROC-ES2L.ssp585.r3i1p1f2.Omon.gn.none.thetao: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/preprocessing.py:233: UserWarning: CMIP.MIROC.MIROC-ES2L.historical.r16i1p1f2.Omon.gn.none.o2: Unit correction failed with: Cannot convert variables:
#     incompatible units for variable 'lev': cannot convert a non-quantity using 'm' as unit
#   warnings.warn(
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.dcpp_init_year.version.time_range.path'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1581' class='' max='1581' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1581/1581 39:17<00:00]
#     </div>

# %% [markdown]
# ## Cleanup datasets early
#
# I am currently:
# - dropping all variables except for the one specified in ds.variable_id
# - Checking if datasets have the expected length (otherwise drop)
#
# I am currently allowing longer ssp585 runs, but could cut them here!

# %%
import warnings

def _expected_length(ds):
    if ds.experiment_id == "historical":
        if ds.table_id == "Omon":
            return 1980
        else:
            warnings.warn(
                f"unknown table_id [{ds.table_id}] for {cmip6_dataset_id(ds)}"
            )
            return 1

    elif "ssp" in ds.experiment_id:
        if ds.table_id == "Omon":
            return 1032
        else:
            warnings.warn(
                f"unknown table_id [{ds.table_id}] for {cmip6_dataset_id(ds)}"
            )
            return 1

    elif "Control" in ds.experiment_id:
        if ds.table_id == "Omon":
            return (
                12 * 50
            )  # just give a low number here so none of the controls are dropped
        else:
            warnings.warn(
                f"unknown table_id [{ds.table_id}] for {cmip6_dataset_id(ds)}"
            )
            return 1
    else:
        warnings.warn(
            f"unknown experiment_id [{ds.experiment_id}] for {cmip6_dataset_id(ds)}"
        )
        return 1


def filter_ddict(ddict):
    ddict_filtered = {}
    for name, ds in ddict.items():
        # drop everything but main variable
        ds = ds.drop([v for v in ds.data_vars if v != ds.variable_id])
        # remove any output in density coordinates (Nor ESM?)
        if not 'rho' in ds.dims:
            # filter out too short runs
            if "time" not in ds.dims:
                ddict_filtered[name] = ds
            else:
                if len(ds.time) < _expected_length(ds):
                    print("---------DROPPED--------")
                    print(name)
                    print(_expected_length(ds))
                    print(len(ds.time))
                    print("---------DROPPED--------")
                else:
                    ddict_filtered[name] = ds
    return ddict_filtered


# apply to data and metrics
ds_dict_filtered = filter_ddict(ds_dict)
ds_metric_dict_filtered = filter_ddict(ds_metric_dict)
# Out:
# ---------DROPPED--------
# CNRM-ESM2-1.gn.historical.Omon.r6i1p1f2.so
# 1980
# 1380
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r18i1p1f1.thkcello
# 1032
# 240
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r7i1p1f1.thkcello
# 1032
# 312
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r17i1p1f1.thkcello
# 1032
# 360
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r25i1p1f1.thkcello
# 1032
# 312
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r19i1p1f1.thkcello
# 1032
# 120
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r12i1p1f1.thkcello
# 1032
# 120
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r21i1p1f1.thkcello
# 1032
# 120
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r13i1p1f1.thkcello
# 1032
# 360
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r30i1p1f1.thkcello
# 1032
# 240
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r16i1p1f1.thkcello
# 1032
# 360
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r26i1p1f1.thkcello
# 1032
# 432
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r24i1p1f1.thkcello
# 1032
# 120
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r20i1p1f1.thkcello
# 1032
# 432
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r15i1p1f1.thkcello
# 1032
# 120
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r29i1p1f1.thkcello
# 1032
# 120
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r6i1p1f1.thkcello
# 1032
# 120
# ---------DROPPED--------
# ---------DROPPED--------
# ACCESS-ESM1-5.gn.ssp245.Omon.r23i1p1f1.thkcello
# 1032
# 120
# ---------DROPPED--------
# /tmp/ipykernel_229624/2467907213.py:33: UserWarning: unknown experiment_id [dcppC-amv-neg] for DCPP.IPSL.IPSL-CM6A-LR.dcppC-amv-neg.r20i1p1f1.Omon.gn.none.thkcello
#   warnings.warn(

# %%
import pathlib
# new files (change in later and get rid of `load_trend_dict` (or refactor?) and `fix_trend_metadata`)
# Load all trend files
flist = list(pathlib.Path('../../data/external/cmip6_control_drifts/').absolute().glob('*.nc'))
flist = [f for f in flist if any([v in str(f) for v in variable_ids])]
trend_dict = {}
for f in progress_bar(flist):
    trend_dict[f.stem] = xr.open_mfdataset([f])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='401' class='' max='401' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [401/401 00:22<00:00]
#     </div>

# %%
# these ones are messed up...need a better way to deal with that in the previous step
# see https://github.com/jbusecke/cmip6_preprocessing/issues/175
incomplete_keys = ['CMIP.IPSL.IPSL-CM6A-LR.historical.r3i1p1f1.Omon.gn.none.area_o2']
trend_dict = {k:ds for k,ds in trend_dict.items() if k not in incomplete_keys}
# i think this should be taken care of in the filtering step above...TODO check at a later point

ddict_tracers_detrended = match_and_remove_trend(
    ds_dict_filtered,
    trend_dict,
)
# Out:
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r13i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r19i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r40i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r31i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r27i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r37i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585.r7i1p1f1.Omon.gn.v20200908.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r25i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r20i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r11i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r12i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r12i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r21i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r13i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r11i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r19i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r18i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r19i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r22i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r34i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r24i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r17i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r15i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r27i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r35i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r30i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r11i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r19i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r39i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r20i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r23i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r23i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r17i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r39i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r23i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r14i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r35i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r20i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r31i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r32i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r24i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r25i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r22i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r20i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r30i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585.r7i1p1f1.Omon.gn.v20200908.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r18i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r26i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r29i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MOHC.UKESM1-0-LL.historical.r19i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r26i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r16i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r25i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r15i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r24i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.IPSL.IPSL-CM6A-LR.historical.r3i1p1f1.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r36i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r27i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r30i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r21i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r28i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r28i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r17i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r27i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r17i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r21i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r19i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r17i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r25i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r23i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r24i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r16i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r22i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r28i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r30i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r7i1p1f1.Omon.gn.v20200529.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r23i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r17i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r18i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r32i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r24i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r16i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r40i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r25i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r7i1p1f1.Omon.gn.v20200529.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r33i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r21i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r21i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585.r7i1p1f1.Omon.gn.v20200908.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r20i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r24i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r19i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r18i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r22i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r25i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r25i1p1f1.Omon.gn.v20200922.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r28i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r38i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r29i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r29i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r13i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r15i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r14i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r21i1p1f1.Omon.gn.v20190429.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r28i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.IPSL.IPSL-CM6A-LR.historical.r32i1p1f1.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r23i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585.r10i1p1f1.Omon.gn.v20200908.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r7i1p1f1.Omon.gn.v20200529.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r21i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r22i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r22i1p1f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r29i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r29i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r20i1p1f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r34i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r37i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r27i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r26i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.r3i1p1f1.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r22i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r1i1000p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r14i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r23i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r19i1p1f1.Omon.gn.v20200803.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r18i1p1f1.Omon.gn.v20200803.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.IPSL.IPSL-CM6A-LR.historical.r32i1p1f1.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r28i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r29i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r26i1p1f1.Omon.gn.v20200922.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r38i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r18i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r18i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r33i1p2f1.Omon.gn.v20190429.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r25i1p1f1.Omon.gn.v20200922.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.IPSL.IPSL-CM6A-LR.historical.r32i1p1f1.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r28i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r26i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r36i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.NIMS-KMA.UKESM1-0-LL.historical.r13i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r26i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r27i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CSIRO.ACCESS-ESM1-5.historical.r12i1p1f1.Omon.gn.v20200803.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.CCCma.CanESM5.historical.r30i1p2f1.Omon.gn.v20190429.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r21i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r14i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r23i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r20i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r17i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MOHC.UKESM1-0-LL.historical.r19i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r19i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r23i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r15i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r21i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r26i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r24i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MOHC.UKESM1-0-LL.historical.r19i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r1i1000p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r30i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.NIMS-KMA.UKESM1-0-LL.historical.r13i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r11i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r22i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r18i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r12i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r17i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r16i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r14i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r1i1000p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r22i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r27i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r17i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r24i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r14i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r16i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r13i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r12i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r12i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r26i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r27i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r20i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r15i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r25i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r30i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r18i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r11i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r20i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r11i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r19i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r13i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r30i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r24i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r29i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.NIMS-KMA.UKESM1-0-LL.historical.r13i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r15i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r13i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r29i1p1f2.Omon.gn.none.thetao
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r28i1p1f2.Omon.gn.none.so
#   warnings.warn(nomatch_msg)
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:60: UserWarning: Could not find a matching dataset for CMIP.MIROC.MIROC-ES2L.historical.r16i1p1f2.Omon.gn.none.o2
#   warnings.warn(nomatch_msg)

# %% [markdown]
# ## Match metrics

# %%
# these cause trouble
problem_metrics = [
    'ACCESS-ESM1-5.gn.ssp585.Omon.r3i1p1f1.thkcello', # metric too short
    'ACCESS-ESM1-5.gn.ssp585.Omon.r2i1p1f1.thkcello', # metric too short
    'ACCESS-ESM1-5.gn.ssp585.Omon.r1i1p1f1.thkcello', # metric too long (I guess I could fix that with a join='inner', but probably not worth it now
    'ACCESS-ESM1-5.gn.ssp585.Omon.r9i1p1f1.thkcello', # metric too short
    'ACCESS-ESM1-5.gn.ssp585.Omon.r6i1p1f1.thkcello', # metric too long (I guess I could fix that with a join='inner', but probably not worth it now
    'ACCESS-ESM1-5.gn.ssp585.Omon.r4i1p1f1.thkcello', # metric too long (I guess I could fix that with a join='inner', but probably not worth it now
    'ACCESS-ESM1-5.gn.ssp585.Omon.r8i1p1f1.thkcello', # metric too long (I guess I could fix that with a join='inner', but probably not worth it now
    'ACCESS-ESM1-5.gn.ssp585.Omon.r10i1p1f1.thkcello', # metric too long (I guess I could fix that with a join='inner', but probably not worth it now
    'ACCESS-ESM1-5.gn.ssp585.Omon.r5i1p1f1.thkcello', # metric too long (I guess I could fix that with a join='inner', but probably not worth it now
]
for key in problem_metrics:
    if key in ds_metric_dict_filtered.keys():
        del ds_metric_dict_filtered[key]

# %%
for k, ds in ddict_tracers_detrended.items():
    print(k, [len(ds[di]) for di in ds.dims])
# Out:
# CanESM5.gn.historical.Omon.r12i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r1i1p1f1.so [3432, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.ssp585.Omon.r5i1p1f2.thetao [1032, 75, 294, 362, 4, 2]
# ACCESS-ESM1-5.gn.ssp585.Omon.r1i1p1f1.so [3072, 50, 300, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r10i1p1f1.o2 [2112, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r14i1p1f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r6i1p1f1.so [3432, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r3i1p1f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r9i1p1f1.thetao [1980, 50, 300, 360, 2, 4]
# CanESM5-CanOE.gn.ssp585.Omon.r3i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r2i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.ssp585.Omon.r1i1p1f2.o2 [1032, 75, 330, 360, 2, 4]
# CanESM5.gn.historical.Omon.r4i1p2f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r8i1p1f1.o2 [3432, 50, 300, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r5i1p1f1.o2 [1632, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r10i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r4i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r6i1p1f1.so [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r5i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r1i1p1f1.o2 [3072, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r14i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r16i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r14i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r3i1p1f1.so [1992, 50, 300, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r2i1p1f1.o2 [3072, 50, 300, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r3i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r5i1p1f1.thetao [2592, 50, 300, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r10i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r16i1p1f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r4i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r6i1p2f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r4i1p1f1.thetao [2112, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r3i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r10i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r15i1p1f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r8i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r9i1p1f1.so [1980, 50, 300, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r9i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r3i1p1f1.so [1032, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r12i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r5i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r9i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r29i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# ACCESS-ESM1-5.gn.historical.Omon.r9i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r2i1p1f1.thetao [1980, 50, 300, 360, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r1i1p1f1.o2 [3432, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r5i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.ssp585.Omon.r4i1p1f2.so [1032, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r2i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r31i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r5i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r4i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r9i1p1f1.so [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r8i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r3i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r10i1p2f1.so [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r5i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# UKESM1-0-LL.gn.ssp585.Omon.r3i1p1f2.so [1032, 75, 330, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r8i1p1f1.so [1032, 40, 220, 256, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r3i1p2f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r10i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r7i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r1i1p1f1.so [3432, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r4i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r1i1p1f1.thetao [3432, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r2i1p1f1.thetao [3432, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r1i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r1i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r2i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r4i1p1f1.so [1980, 50, 300, 360, 2, 4]
# CanESM5-CanOE.gn.ssp585.Omon.r1i1p2f1.so [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r2i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r2i1p1f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r1i1p2f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r4i1p2f1.so [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r9i1p1f1.o2 [3432, 50, 300, 360, 2, 4]
# UKESM1-0-LL.gn.ssp585.Omon.r8i1p1f2.so [1032, 75, 330, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r1i1p1f1.so [1980, 40, 220, 256, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r3i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r5i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r9i1p2f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r9i1p1f1.so [3432, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r6i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r9i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.historical.Omon.r16i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r4i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.historical.Omon.r1i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r7i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r26i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r31i1p1f1.so [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.ssp585.Omon.r2i1p1f2.thetao [1032, 75, 330, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r7i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.historical.Omon.r2i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r11i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r6i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r5i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r9i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r8i1p1f1.so [2112, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r9i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# CanESM5-CanOE.gn.ssp585.Omon.r1i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r1i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r9i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r8i1p2f1.so [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r2i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r6i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r10i1p1f2.so [1980, 75, 330, 360, 2, 4]
# CanESM5.gn.historical.Omon.r3i1p2f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r1i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r9i1p1f1.so [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r1i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r11i1p1f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r10i1p1f1.so [1032, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r3i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r5i1p1f1.thetao [1980, 50, 300, 360, 2, 4]
# CanESM5-CanOE.gn.ssp585.Omon.r2i1p2f1.so [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r6i1p1f1.thetao [3432, 50, 300, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r2i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r7i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r2i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r23i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r12i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# ACCESS-ESM1-5.gn.ssp585.Omon.r2i1p1f1.so [3432, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r3i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r9i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r4i1p1f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r3i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r5i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r13i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r8i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r4i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r2i1p2f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r1i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r11i1p1f2.so [1980, 75, 330, 360, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r2i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r9i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r7i1p1f3.so [1980, 75, 330, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r5i1p1f1.so [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r5i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r8i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r10i1p1f1.so [3432, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r2i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r7i1p1f1.so [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r12i1p1f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r3i1p1f1.thetao [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r6i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r3i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r8i1p1f1.thetao [1272, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r3i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r12i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# CanESM5-CanOE.gn.ssp585.Omon.r2i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r19i1p1f1.so [1980, 75, 332, 362, 4, 2]
# ACCESS-ESM1-5.gn.ssp585.Omon.r6i1p1f1.o2 [2952, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r6i1p2f1.so [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r2i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r5i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r10i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r4i1p1f2.so [1980, 75, 294, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r9i1p1f2.so [1980, 75, 330, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r8i1p1f1.thetao [1980, 50, 300, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r4i1p1f1.so [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r5i1p2f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r3i1p1f1.thetao [1632, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r15i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r2i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r3i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r5i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r6i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r9i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r5i1p1f3.thetao [1980, 75, 330, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r5i1p1f1.so [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r7i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r8i1p1f1.so [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r13i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r7i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r4i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r12i1p1f1.so [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.historical.Omon.r5i1p1f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r1i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r2i1p1f1.so [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r16i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r7i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r1i1p1f2.so [1980, 75, 294, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r27i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.historical.Omon.r8i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r3i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r4i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r5i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r10i1p1f2.so [1980, 2, 63, 256, 360, 4]
# CanESM5.gn.ssp585.Omon.r8i1p1f1.so [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r1i1p1f1.thetao [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r10i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r4i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r9i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r9i1p1f1.thetao [1632, 50, 300, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r2i1p1f1.so [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r2i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r6i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r7i1p2f1.so [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r10i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# CanESM5.gn.historical.Omon.r7i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r10i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# CanESM5.gn.historical.Omon.r1i1p1f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r7i1p1f1.so [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r1i1p1f1.thetao [2952, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r9i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r7i1p2f1.so [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r5i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r25i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r1i1p1f1.so [1032, 40, 220, 256, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r6i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.ssp585.Omon.r2i1p1f2.o2 [1032, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r7i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r1i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.historical.Omon.r11i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r11i1p1f1.so [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r3i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r3i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r1i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r10i1p1f1.so [1032, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r4i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r10i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r4i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r8i1p1f1.so [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r6i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r10i1p1f2.so [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r5i1p1f1.so [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r1i1p2f1.so [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r4i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r6i1p1f1.so [1980, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r8i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r7i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.historical.Omon.r4i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r10i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.historical.Omon.r10i1p2f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r5i1p2f1.so [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r3i1p1f1.so [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r6i1p1f1.so [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r7i1p1f1.so [1032, 40, 220, 256, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r6i1p1f1.thetao [1980, 50, 300, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r12i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r4i1p1f1.so [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r13i1p1f1.so [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.ssp585.Omon.r4i1p1f2.so [1032, 75, 330, 360, 2, 4]
# CanESM5-CanOE.gn.ssp585.Omon.r1i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r1i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r10i1p1f1.so [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r2i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r2i1p1f1.so [1980, 50, 300, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r10i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r8i1p1f1.so [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r5i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r25i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.historical.Omon.r9i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r15i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r11i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r6i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r8i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r1i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# MPI-ESM1-2-LR.gn.historical.Omon.r9i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r5i1p1f1.so [2592, 50, 300, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r6i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r3i1p1f2.so [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r10i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# CanESM5.gn.historical.Omon.r9i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r14i1p1f1.so [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r11i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.ssp585.Omon.r2i1p1f2.thetao [1032, 75, 294, 362, 4, 2]
# ACCESS-ESM1-5.gn.ssp585.Omon.r3i1p1f1.o2 [1152, 50, 300, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r9i1p1f1.so [1032, 40, 220, 256, 2, 4]
# CNRM-ESM2-1.gn.ssp585.Omon.r1i1p1f2.thetao [1032, 75, 294, 362, 4, 2]
# MPI-ESM1-2-LR.gn.historical.Omon.r10i1p1f1.so [1980, 40, 220, 256, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r1i1p1f1.so [1980, 50, 300, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r8i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r6i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.ssp585.Omon.r2i1p1f2.so [1032, 75, 294, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r1i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r21i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r6i1p1f3.so [1980, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r13i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r16i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r10i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# IPSL-CM6A-LR.gn.ssp585.Omon.r3i1p1f1.thetao [1032, 75, 332, 362, 4, 2]
# CanESM5.gn.historical.Omon.r15i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r22i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.historical.Omon.r8i1p1f1.o2 [1980, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r5i1p1f1.so [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r4i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r10i1p1f1.thetao [1980, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r16i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r1i1p2f1.so [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r1i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r7i1p1f1.so [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r7i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r3i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r8i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.ssp585.Omon.r4i1p1f1.so [1512, 50, 300, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r20i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.ssp585.Omon.r14i1p1f1.thetao [1032, 75, 332, 362, 4, 2]
# CanESM5.gn.historical.Omon.r7i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r12i1p1f2.so [1980, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r1i1p1f1.thetao [3432, 75, 332, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r2i1p1f1.so [1032, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r4i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r4i1p1f2.so [1980, 75, 330, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r11i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r8i1p1f2.so [1980, 75, 294, 362, 4, 2]
# MPI-ESM1-2-LR.gn.historical.Omon.r9i1p1f1.so [1980, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r6i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r18i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# CanESM5.gn.historical.Omon.r8i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r3i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r6i1p1f3.o2 [1980, 75, 330, 360, 2, 4]
# CanESM5.gn.historical.Omon.r7i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r8i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r3i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r2i1p1f2.so [1980, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r19i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r2i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r5i1p1f1.so [1032, 40, 220, 256, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r6i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r2i1p2f1.so [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r14i1p1f1.so [1032, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r5i1p1f3.so [1980, 75, 330, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r8i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.historical.Omon.r6i1p1f1.so [1980, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r29i1p1f1.so [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r1i1p1f1.o2 [3432, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r8i1p1f2.so [1980, 75, 330, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r17i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r1i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r4i1p1f1.thetao [1980, 50, 300, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r2i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r4i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r9i1p1f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.historical.Omon.r7i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r5i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r23i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r7i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r12i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# CanESM5-CanOE.gn.historical.Omon.r1i1p2f1.thetao [1980, 45, 291, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r1i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r5i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r1i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r2i1p1f1.o2 [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r6i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r17i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r17i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r3i1p1f2.so [1980, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r6i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r8i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r9i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.historical.Omon.r10i1p1f1.thetao [1980, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r10i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r6i1p1f3.thetao [1980, 75, 330, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r2i1p2f1.so [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.ssp585.Omon.r5i1p1f2.so [1032, 75, 294, 362, 4, 2]
# UKESM1-0-LL.gn.ssp585.Omon.r2i1p1f2.so [1032, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r3i1p1f1.so [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.ssp585.Omon.r8i1p1f2.thetao [1032, 75, 330, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r10i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r3i1p1f1.o2 [1032, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.ssp585.Omon.r2i1p1f2.o2 [1032, 75, 330, 360, 2, 4]
# ACCESS-ESM1-5.gn.historical.Omon.r10i1p1f1.so [1980, 50, 300, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r4i1p1f1.thetao [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.ssp585.Omon.r3i1p1f2.o2 [1032, 75, 294, 362, 4, 2]
# ACCESS-ESM1-5.gn.ssp585.Omon.r4i1p1f1.o2 [1632, 50, 300, 360, 2, 4]
# CanESM5.gn.historical.Omon.r8i1p2f1.so [1980, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r8i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r25i1p1f1.so [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r6i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r9i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r4i1p1f1.so [1032, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r3i1p1f1.so [1032, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r2i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r9i1p1f2.so [1980, 75, 294, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r5i1p1f3.o2 [1980, 75, 330, 360, 2, 4]
# MPI-ESM1-2-LR.gn.historical.Omon.r3i1p1f1.so [1980, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r6i1p2f1.thetao [1032, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.ssp585.Omon.r3i1p1f2.thetao [1032, 75, 330, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r18i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r10i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# CanESM5.gn.ssp585.Omon.r9i1p2f1.so [1032, 45, 291, 360, 2, 4]
# CanESM5.gn.ssp585.Omon.r3i1p1f1.so [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r7i1p1f2.so [1980, 75, 294, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r10i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r7i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# CanESM5.gn.historical.Omon.r10i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r3i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r6i1p1f1.o2 [1032, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.ssp585.Omon.r8i1p1f2.o2 [1032, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r21i1p1f1.so [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r8i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r14i1p1f1.o2 [1032, 75, 332, 362, 4, 2]
# CanESM5-CanOE.gn.ssp585.Omon.r2i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r30i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r4i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r28i1p1f1.so [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r7i1p1f3.thetao [1980, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r14i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r6i1p1f2.so [1032, 2, 63, 256, 360, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r2i1p1f1.so [1032, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r27i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r3i1p1f2.so [1032, 2, 63, 256, 360, 4]
# CanESM5-CanOE.gn.ssp585.Omon.r3i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r20i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r3i1p2f1.so [1032, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r2i1p1f2.so [1980, 75, 294, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r1i1p1f2.so [1980, 75, 330, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r2i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r5i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r2i1p1f2.so [1032, 2, 63, 256, 360, 4]
# CNRM-ESM2-1.gn.ssp585.Omon.r3i1p1f2.thetao [1032, 75, 294, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r7i1p1f3.o2 [1980, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r8i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r9i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r24i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r16i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r7i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r15i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.ssp585.Omon.r3i1p1f2.so [1032, 75, 294, 362, 4, 2]
# UKESM1-0-LL.gn.ssp585.Omon.r1i1p1f2.thetao [1032, 75, 330, 360, 2, 4]
# MIROC-ES2L.gn.ssp585.Omon.r7i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# CanESM5-CanOE.gn.ssp585.Omon.r3i1p2f1.so [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r24i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r8i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r15i1p1f1.so [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.ssp585.Omon.r4i1p1f2.o2 [1032, 75, 330, 360, 2, 4]
# MIROC-ES2L.gn.ssp585.Omon.r4i1p1f2.so [1032, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r19i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r5i1p1f2.so [1980, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r3i1p1f2.thetao [1980, 75, 294, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r2i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r30i1p1f1.so [1980, 75, 332, 362, 4, 2]
# CanESM5.gn.historical.Omon.r8i1p2f1.o2 [1980, 45, 291, 360, 2, 4]
# CNRM-ESM2-1.gn.historical.Omon.r4i1p1f2.o2 [1980, 75, 294, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r8i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# MIROC-ES2L.gn.ssp585.Omon.r6i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r9i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# UKESM1-0-LL.gn.historical.Omon.r17i1p1f2.so [1980, 75, 330, 360, 2, 4]
# MIROC-ES2L.gn.ssp585.Omon.r5i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r2i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r6i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.ssp585.Omon.r6i1p1f1.thetao [1032, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r3i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# CanESM5.gn.ssp585.Omon.r4i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r18i1p1f2.so [1980, 75, 330, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r9i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r21i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r4i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# CNRM-ESM2-1.gn.ssp585.Omon.r5i1p1f2.o2 [1032, 75, 294, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r28i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r2i1p1f1.thetao [1032, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r11i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# UKESM1-0-LL.gn.historical.Omon.r1i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r16i1p1f1.so [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.ssp585.Omon.r4i1p1f2.thetao [1032, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.historical.Omon.r11i1p1f2.so [1980, 75, 294, 362, 4, 2]
# CanESM5.gn.ssp585.Omon.r5i1p2f1.o2 [1032, 45, 291, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r11i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r17i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r9i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r16i1p1f2.so [1980, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r6i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r9i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r22i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r29i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r10i1p1f1.so [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r3i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r31i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r8i1p1f1.so [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r11i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# MIROC-ES2L.gn.ssp585.Omon.r10i1p1f2.so [1032, 2, 63, 256, 360, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r1i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r18i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r8i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r14i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r9i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r1i1p1f2.so [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r26i1p1f1.so [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r9i1p1f2.so [1032, 2, 63, 256, 360, 4]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r2i1p1f1.o2 [1032, 40, 220, 256, 2, 4]
# UKESM1-0-LL.gn.ssp585.Omon.r1i1p1f2.so [1032, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r4i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MPI-ESM1-2-LR.gn.ssp585.Omon.r6i1p1f1.so [1032, 40, 220, 256, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r4i1p1f1.o2 [1032, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r22i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r7i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# UKESM1-0-LL.gn.ssp585.Omon.r4i1p1f2.thetao [1032, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r4i1p1f1.thetao [1032, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r7i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r13i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r8i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# UKESM1-0-LL.gn.historical.Omon.r3i1p1f2.o2 [1980, 75, 330, 360, 2, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r2i1p1f1.thetao [1032, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r28i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r1i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r7i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r23i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r13i1p1f1.so [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r7i1p1f2.so [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r3i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r10i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r18i1p1f1.so [1980, 75, 332, 362, 4, 2]
# CNRM-ESM2-1.gn.ssp585.Omon.r1i1p1f2.so [1032, 75, 294, 362, 4, 2]
# UKESM1-0-LL.gn.historical.Omon.r3i1p1f2.so [1980, 75, 330, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r6i1p1f2.so [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r4i1p1f2.so [1980, 2, 63, 256, 360, 4]
# UKESM1-0-LL.gn.ssp585.Omon.r3i1p1f2.o2 [1032, 75, 330, 360, 2, 4]
# MIROC-ES2L.gn.historical.Omon.r6i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r5i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r8i1p1f2.so [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r5i1p1f2.so [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r7i1p1f2.so [1980, 2, 63, 256, 360, 4]
# UKESM1-0-LL.gn.historical.Omon.r17i1p1f2.thetao [1980, 75, 330, 360, 2, 4]
# CNRM-ESM2-1.gn.ssp585.Omon.r1i1p1f2.o2 [1032, 75, 294, 362, 4, 2]
# CNRM-ESM2-1.gn.ssp585.Omon.r4i1p1f2.o2 [1032, 75, 294, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r4i1p1f2.o2 [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r18i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.ssp585.Omon.r2i1p1f1.o2 [1032, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r20i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.historical.Omon.r30i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r10i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r24i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r2i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r8i1p1f2.so [1032, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r26i1p1f1.o2 [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r5i1p1f2.so [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r4i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r2i1p1f1.thetao [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r5i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r8i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r2i1p1f1.so [1032, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r9i1p1f2.so [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r27i1p1f1.so [1980, 75, 332, 362, 4, 2]
# IPSL-CM6A-LR.gn.ssp585.Omon.r6i1p1f1.so [1032, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.historical.Omon.r1i1p1f2.thetao [1980, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r1i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.historical.Omon.r1i1p1f1.so [1980, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r10i1p1f2.thetao [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r1i1p1f2.so [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.historical.Omon.r2i1p1f2.so [1980, 2, 63, 256, 360, 4]
# IPSL-CM6A-LR.gn.ssp585.Omon.r4i1p1f1.so [1032, 75, 332, 362, 4, 2]
# MIROC-ES2L.gn.ssp585.Omon.r6i1p1f2.o2 [1032, 2, 63, 256, 360, 4]
# MIROC-ES2L.gn.ssp585.Omon.r3i1p1f2.thetao [1032, 2, 63, 256, 360, 4]

# %% [markdown]
# ### EPC gives me problems (this needs to be raised in cmip6_pp)...
# When trying to match 3d metrics with 2d data, things fail. I need a quick workaround and an elegant one for now

# %%
# this one causes problems because the time is not as long as the full data...apparently they stopped writing the thickness
ddict_tracers_detrended_filtered = {
    k: ds.squeeze()
    for k, ds in ddict_tracers_detrended.items()
    if not ("ACCESS-ESM1-5" in k and "r3i1p1f1" in k)
}

# check out quickly which model has the problem here
ddict_tracers_detrended_filtered = {k:ds for k,ds in ddict_tracers_detrended_filtered.items() if 'epc' not in k}

ddict_matched_3d = match_metrics(
    ddict_tracers_detrended_filtered,
    ds_metric_dict_filtered,
    ["areacello", "thkcello"],
    print_statistics=True,
)

# # check out quickly which model has the problem here
# ddict_tracers_detrended_filtered = {k:ds for k,ds in ddict_tracers_detrended_filtered.items() if 'epc' in k}

# ddict_matched_2d = match_metrics(
#     ddict_tracers_detrended_filtered,
#     ds_metric_dict_filtered,
#     ["areacello"],
#     print_statistics=True,
# )

# ddict_matched = ddict_matched_3d.update(ddict_matched_2d)
ddict_matched = ddict_matched_3d
# Out:
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:636: UserWarning: This metric had a time dimension and did not perfectly match. Not parsing anything.
#   warnings.warn(
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:615: UserWarning: No matching metrics found for thkcello
#   warnings.warn(f"No matching metrics found for {mv}")
# Processed 538 datasets.
# Exact matches:{'areacello': 0, 'thkcello': 276}
# Other matches:{'areacello': 538, 'thkcello': 161}
# No match found:{'areacello': 0, 'thkcello': 60}

# %% [markdown]
# ## Interpolate Grids and merge variables
#
# - handle the Norwegian Models inside `interpolate_grid_label` (TODO: Check if this works)

# %% [markdown]
# TODO: EPC also gives trouble here...

# %%
import dask
with dask.config.set(**{'array.slicing.split_large_chunks': True}): # only necessary for ACCESS, they are all different lengths?

    print("interpolate grids\n")
    ddict_matched_regrid = interpolate_grid_label(
        ddict_matched, merge_kwargs={"compat": "override"}
    )  # This should be a default soon

# #patch the norwegian model in manually
# ddict_patch = merge_variables(ddict_matched)
# for name, ds in ddict_patch.items():
#     if 'Nor' in name and 'gr' in name:
#         patch_name = name.replace('.gr','')
#         ddict_matched_regrid[patch_name] = ds
# Out:
# interpolate grids

# %%
np.sort(list(ddict_matched_regrid.keys()))
# Out:
# array(['ACCESS-ESM1-5.historical.Omon.r10i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r1i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r2i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r4i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r5i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r6i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r8i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r9i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r10i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r1i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r2i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r4i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r5i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r6i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r8i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r9i1p1f1',
#        'CNRM-ESM2-1.historical.Omon.r10i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r11i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r1i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r2i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r3i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r4i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r5i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r6i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r7i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r8i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r9i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r1i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r2i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r3i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r4i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r5i1p1f2',
#        'CanESM5-CanOE.historical.Omon.r1i1p2f1',
#        'CanESM5-CanOE.historical.Omon.r2i1p2f1',
#        'CanESM5-CanOE.historical.Omon.r3i1p2f1',
#        'CanESM5-CanOE.ssp585.Omon.r1i1p2f1',
#        'CanESM5-CanOE.ssp585.Omon.r2i1p2f1',
#        'CanESM5-CanOE.ssp585.Omon.r3i1p2f1',
#        'CanESM5.historical.Omon.r10i1p1f1',
#        'CanESM5.historical.Omon.r10i1p2f1',
#        'CanESM5.historical.Omon.r11i1p1f1',
#        'CanESM5.historical.Omon.r12i1p1f1',
#        'CanESM5.historical.Omon.r13i1p1f1',
#        'CanESM5.historical.Omon.r14i1p1f1',
#        'CanESM5.historical.Omon.r15i1p1f1',
#        'CanESM5.historical.Omon.r16i1p1f1',
#        'CanESM5.historical.Omon.r1i1p1f1',
#        'CanESM5.historical.Omon.r1i1p2f1',
#        'CanESM5.historical.Omon.r2i1p1f1',
#        'CanESM5.historical.Omon.r2i1p2f1',
#        'CanESM5.historical.Omon.r3i1p1f1',
#        'CanESM5.historical.Omon.r3i1p2f1',
#        'CanESM5.historical.Omon.r4i1p1f1',
#        'CanESM5.historical.Omon.r4i1p2f1',
#        'CanESM5.historical.Omon.r5i1p1f1',
#        'CanESM5.historical.Omon.r5i1p2f1',
#        'CanESM5.historical.Omon.r6i1p1f1',
#        'CanESM5.historical.Omon.r6i1p2f1',
#        'CanESM5.historical.Omon.r7i1p1f1',
#        'CanESM5.historical.Omon.r7i1p2f1',
#        'CanESM5.historical.Omon.r8i1p1f1',
#        'CanESM5.historical.Omon.r8i1p2f1',
#        'CanESM5.historical.Omon.r9i1p1f1',
#        'CanESM5.historical.Omon.r9i1p2f1',
#        'CanESM5.ssp585.Omon.r10i1p1f1', 'CanESM5.ssp585.Omon.r10i1p2f1',
#        'CanESM5.ssp585.Omon.r1i1p1f1', 'CanESM5.ssp585.Omon.r1i1p2f1',
#        'CanESM5.ssp585.Omon.r2i1p1f1', 'CanESM5.ssp585.Omon.r2i1p2f1',
#        'CanESM5.ssp585.Omon.r3i1p1f1', 'CanESM5.ssp585.Omon.r3i1p2f1',
#        'CanESM5.ssp585.Omon.r4i1p1f1', 'CanESM5.ssp585.Omon.r4i1p2f1',
#        'CanESM5.ssp585.Omon.r5i1p1f1', 'CanESM5.ssp585.Omon.r5i1p2f1',
#        'CanESM5.ssp585.Omon.r6i1p1f1', 'CanESM5.ssp585.Omon.r6i1p2f1',
#        'CanESM5.ssp585.Omon.r7i1p1f1', 'CanESM5.ssp585.Omon.r7i1p2f1',
#        'CanESM5.ssp585.Omon.r8i1p1f1', 'CanESM5.ssp585.Omon.r8i1p2f1',
#        'CanESM5.ssp585.Omon.r9i1p1f1', 'CanESM5.ssp585.Omon.r9i1p2f1',
#        'IPSL-CM6A-LR.historical.Omon.r10i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r11i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r12i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r13i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r14i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r15i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r16i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r17i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r18i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r19i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r1i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r20i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r21i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r22i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r23i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r24i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r25i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r26i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r27i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r28i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r29i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r2i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r30i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r31i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r3i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r4i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r5i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r6i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r7i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r8i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r9i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r14i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r1i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r2i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r3i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r4i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r6i1p1f1',
#        'MIROC-ES2L.historical.Omon.r10i1p1f2',
#        'MIROC-ES2L.historical.Omon.r1i1p1f2',
#        'MIROC-ES2L.historical.Omon.r2i1p1f2',
#        'MIROC-ES2L.historical.Omon.r3i1p1f2',
#        'MIROC-ES2L.historical.Omon.r4i1p1f2',
#        'MIROC-ES2L.historical.Omon.r5i1p1f2',
#        'MIROC-ES2L.historical.Omon.r6i1p1f2',
#        'MIROC-ES2L.historical.Omon.r7i1p1f2',
#        'MIROC-ES2L.historical.Omon.r8i1p1f2',
#        'MIROC-ES2L.historical.Omon.r9i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r10i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r1i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r2i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r3i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r4i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r5i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r6i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r7i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r8i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r9i1p1f2',
#        'MPI-ESM1-2-LR.historical.Omon.r10i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r1i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r2i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r3i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r4i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r5i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r6i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r7i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r8i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r9i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r10i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r1i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r2i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r3i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r4i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r5i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r6i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r7i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r8i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r9i1p1f1',
#        'UKESM1-0-LL.historical.Omon.r10i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r11i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r12i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r16i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r17i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r18i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r1i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r2i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r3i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r4i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r5i1p1f3',
#        'UKESM1-0-LL.historical.Omon.r6i1p1f3',
#        'UKESM1-0-LL.historical.Omon.r7i1p1f3',
#        'UKESM1-0-LL.historical.Omon.r8i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r9i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r1i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r2i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r3i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r4i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r8i1p1f2'], dtype='<U39')

# %%
# TODO: This needs to go to cmip6_pp: Force remove the attr that was just combined by, otherwise subsequent steps fail
def _del_attr(ds, attr):
    if attr in ds.attrs:
        del ds.attrs[attr]
    return ds

ddict_matched_regrid = {k:_del_attr(ds, 'variable_id') for k,ds in ddict_matched_regrid.items()}

# %%
np.sort(list(ddict_matched_regrid.keys()))
# Out:
# array(['ACCESS-ESM1-5.historical.Omon.r10i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r1i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r2i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r4i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r5i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r6i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r8i1p1f1',
#        'ACCESS-ESM1-5.historical.Omon.r9i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r10i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r1i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r2i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r4i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r5i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r6i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r8i1p1f1',
#        'ACCESS-ESM1-5.ssp585.Omon.r9i1p1f1',
#        'CNRM-ESM2-1.historical.Omon.r10i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r11i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r1i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r2i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r3i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r4i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r5i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r6i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r7i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r8i1p1f2',
#        'CNRM-ESM2-1.historical.Omon.r9i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r1i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r2i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r3i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r4i1p1f2',
#        'CNRM-ESM2-1.ssp585.Omon.r5i1p1f2',
#        'CanESM5-CanOE.historical.Omon.r1i1p2f1',
#        'CanESM5-CanOE.historical.Omon.r2i1p2f1',
#        'CanESM5-CanOE.historical.Omon.r3i1p2f1',
#        'CanESM5-CanOE.ssp585.Omon.r1i1p2f1',
#        'CanESM5-CanOE.ssp585.Omon.r2i1p2f1',
#        'CanESM5-CanOE.ssp585.Omon.r3i1p2f1',
#        'CanESM5.historical.Omon.r10i1p1f1',
#        'CanESM5.historical.Omon.r10i1p2f1',
#        'CanESM5.historical.Omon.r11i1p1f1',
#        'CanESM5.historical.Omon.r12i1p1f1',
#        'CanESM5.historical.Omon.r13i1p1f1',
#        'CanESM5.historical.Omon.r14i1p1f1',
#        'CanESM5.historical.Omon.r15i1p1f1',
#        'CanESM5.historical.Omon.r16i1p1f1',
#        'CanESM5.historical.Omon.r1i1p1f1',
#        'CanESM5.historical.Omon.r1i1p2f1',
#        'CanESM5.historical.Omon.r2i1p1f1',
#        'CanESM5.historical.Omon.r2i1p2f1',
#        'CanESM5.historical.Omon.r3i1p1f1',
#        'CanESM5.historical.Omon.r3i1p2f1',
#        'CanESM5.historical.Omon.r4i1p1f1',
#        'CanESM5.historical.Omon.r4i1p2f1',
#        'CanESM5.historical.Omon.r5i1p1f1',
#        'CanESM5.historical.Omon.r5i1p2f1',
#        'CanESM5.historical.Omon.r6i1p1f1',
#        'CanESM5.historical.Omon.r6i1p2f1',
#        'CanESM5.historical.Omon.r7i1p1f1',
#        'CanESM5.historical.Omon.r7i1p2f1',
#        'CanESM5.historical.Omon.r8i1p1f1',
#        'CanESM5.historical.Omon.r8i1p2f1',
#        'CanESM5.historical.Omon.r9i1p1f1',
#        'CanESM5.historical.Omon.r9i1p2f1',
#        'CanESM5.ssp585.Omon.r10i1p1f1', 'CanESM5.ssp585.Omon.r10i1p2f1',
#        'CanESM5.ssp585.Omon.r1i1p1f1', 'CanESM5.ssp585.Omon.r1i1p2f1',
#        'CanESM5.ssp585.Omon.r2i1p1f1', 'CanESM5.ssp585.Omon.r2i1p2f1',
#        'CanESM5.ssp585.Omon.r3i1p1f1', 'CanESM5.ssp585.Omon.r3i1p2f1',
#        'CanESM5.ssp585.Omon.r4i1p1f1', 'CanESM5.ssp585.Omon.r4i1p2f1',
#        'CanESM5.ssp585.Omon.r5i1p1f1', 'CanESM5.ssp585.Omon.r5i1p2f1',
#        'CanESM5.ssp585.Omon.r6i1p1f1', 'CanESM5.ssp585.Omon.r6i1p2f1',
#        'CanESM5.ssp585.Omon.r7i1p1f1', 'CanESM5.ssp585.Omon.r7i1p2f1',
#        'CanESM5.ssp585.Omon.r8i1p1f1', 'CanESM5.ssp585.Omon.r8i1p2f1',
#        'CanESM5.ssp585.Omon.r9i1p1f1', 'CanESM5.ssp585.Omon.r9i1p2f1',
#        'IPSL-CM6A-LR.historical.Omon.r10i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r11i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r12i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r13i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r14i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r15i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r16i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r17i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r18i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r19i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r1i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r20i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r21i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r22i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r23i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r24i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r25i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r26i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r27i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r28i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r29i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r2i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r30i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r31i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r3i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r4i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r5i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r6i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r7i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r8i1p1f1',
#        'IPSL-CM6A-LR.historical.Omon.r9i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r14i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r1i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r2i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r3i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r4i1p1f1',
#        'IPSL-CM6A-LR.ssp585.Omon.r6i1p1f1',
#        'MIROC-ES2L.historical.Omon.r10i1p1f2',
#        'MIROC-ES2L.historical.Omon.r1i1p1f2',
#        'MIROC-ES2L.historical.Omon.r2i1p1f2',
#        'MIROC-ES2L.historical.Omon.r3i1p1f2',
#        'MIROC-ES2L.historical.Omon.r4i1p1f2',
#        'MIROC-ES2L.historical.Omon.r5i1p1f2',
#        'MIROC-ES2L.historical.Omon.r6i1p1f2',
#        'MIROC-ES2L.historical.Omon.r7i1p1f2',
#        'MIROC-ES2L.historical.Omon.r8i1p1f2',
#        'MIROC-ES2L.historical.Omon.r9i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r10i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r1i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r2i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r3i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r4i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r5i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r6i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r7i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r8i1p1f2',
#        'MIROC-ES2L.ssp585.Omon.r9i1p1f2',
#        'MPI-ESM1-2-LR.historical.Omon.r10i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r1i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r2i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r3i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r4i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r5i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r6i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r7i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r8i1p1f1',
#        'MPI-ESM1-2-LR.historical.Omon.r9i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r10i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r1i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r2i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r3i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r4i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r5i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r6i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r7i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r8i1p1f1',
#        'MPI-ESM1-2-LR.ssp585.Omon.r9i1p1f1',
#        'UKESM1-0-LL.historical.Omon.r10i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r11i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r12i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r16i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r17i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r18i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r1i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r2i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r3i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r4i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r5i1p1f3',
#        'UKESM1-0-LL.historical.Omon.r6i1p1f3',
#        'UKESM1-0-LL.historical.Omon.r7i1p1f3',
#        'UKESM1-0-LL.historical.Omon.r8i1p1f2',
#        'UKESM1-0-LL.historical.Omon.r9i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r1i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r2i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r3i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r4i1p1f2',
#        'UKESM1-0-LL.ssp585.Omon.r8i1p1f2'], dtype='<U39')

# %% [markdown]
# ## Concatenate experiments and pick only 'full (both hist and ssp)' runs

# %%
ddict_ex_combined = concat_experiments(
    ddict_matched_regrid,
    concat_kwargs={
        'combine_attrs': 'drop_conflicts',
        'compat': 'override',
        'coords': 'minimal'
    }
)
# Out:
# /home/jbusecke/code/miniconda/envs/cmip6_omz/lib/python3.9/site-packages/cmip6_preprocessing/postprocessing.py:113: UserWarning: Match attributes ['variable_id'] not found in any of the datasets.         This can happen when several combination functions are used.
#   warnings.warn(

# %% [markdown]
# Still need to deal with the access stuff here...

# %%
# only pick full runs (historical and ssp585)
ddict_ex_combined_full = {k:ds for k,ds in ddict_ex_combined.items() if len(ds.time)>3000}

# # TODO/!!! this eliminates some of the models I would like to show? O2 only (for now that should be fine)
# ddict_ex_combined_full = {k:ds for k,ds in ddict_ex_combined_full.items() if not fail_age(ds)}
list(np.sort(list(ddict_ex_combined_full.keys())))
# Out:
# ['ACCESS-ESM1-5.gn.Omon.r10i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r1i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r2i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r4i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r5i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r6i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r8i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r9i1p1f1',
#  'CNRM-ESM2-1.gn.Omon.r1i1p1f2',
#  'CNRM-ESM2-1.gn.Omon.r2i1p1f2',
#  'CNRM-ESM2-1.gn.Omon.r3i1p1f2',
#  'CNRM-ESM2-1.gn.Omon.r4i1p1f2',
#  'CNRM-ESM2-1.gn.Omon.r5i1p1f2',
#  'CanESM5-CanOE.gn.Omon.r1i1p2f1',
#  'CanESM5-CanOE.gn.Omon.r2i1p2f1',
#  'CanESM5-CanOE.gn.Omon.r3i1p2f1',
#  'CanESM5.gn.Omon.r10i1p1f1',
#  'CanESM5.gn.Omon.r10i1p2f1',
#  'CanESM5.gn.Omon.r1i1p1f1',
#  'CanESM5.gn.Omon.r1i1p2f1',
#  'CanESM5.gn.Omon.r2i1p1f1',
#  'CanESM5.gn.Omon.r2i1p2f1',
#  'CanESM5.gn.Omon.r3i1p1f1',
#  'CanESM5.gn.Omon.r3i1p2f1',
#  'CanESM5.gn.Omon.r4i1p1f1',
#  'CanESM5.gn.Omon.r4i1p2f1',
#  'CanESM5.gn.Omon.r5i1p1f1',
#  'CanESM5.gn.Omon.r5i1p2f1',
#  'CanESM5.gn.Omon.r6i1p1f1',
#  'CanESM5.gn.Omon.r6i1p2f1',
#  'CanESM5.gn.Omon.r7i1p1f1',
#  'CanESM5.gn.Omon.r7i1p2f1',
#  'CanESM5.gn.Omon.r8i1p1f1',
#  'CanESM5.gn.Omon.r8i1p2f1',
#  'CanESM5.gn.Omon.r9i1p1f1',
#  'CanESM5.gn.Omon.r9i1p2f1',
#  'IPSL-CM6A-LR.gn.Omon.r14i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r2i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r3i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r4i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r6i1p1f1',
#  'MIROC-ES2L.gn.Omon.r10i1p1f2',
#  'MIROC-ES2L.gn.Omon.r1i1p1f2',
#  'MIROC-ES2L.gn.Omon.r2i1p1f2',
#  'MIROC-ES2L.gn.Omon.r3i1p1f2',
#  'MIROC-ES2L.gn.Omon.r4i1p1f2',
#  'MIROC-ES2L.gn.Omon.r5i1p1f2',
#  'MIROC-ES2L.gn.Omon.r6i1p1f2',
#  'MIROC-ES2L.gn.Omon.r7i1p1f2',
#  'MIROC-ES2L.gn.Omon.r8i1p1f2',
#  'MIROC-ES2L.gn.Omon.r9i1p1f2',
#  'MPI-ESM1-2-LR.gn.Omon.r10i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r1i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r2i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r3i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r4i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r5i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r6i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r7i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r8i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r9i1p1f1',
#  'UKESM1-0-LL.gn.Omon.r1i1p1f2',
#  'UKESM1-0-LL.gn.Omon.r2i1p1f2',
#  'UKESM1-0-LL.gn.Omon.r3i1p1f2',
#  'UKESM1-0-LL.gn.Omon.r4i1p1f2',
#  'UKESM1-0-LL.gn.Omon.r8i1p1f2']

# %% [markdown]
# ## Check for problems and fix missing area/thickness manually
#
# This should be wrapped and brought upstream

# %%
from cmip6_preprocessing.grids import combine_staggered_grid
problems = {'missing_variables':[], 'missing_area':[], 'missing_thickness':[], 'reconstructed_area':[], 'reconstructed_thickness':[]}
ddict_filtered = {}
for name, ds in ddict_ex_combined_full.items():
    flag = False
    # Check that all necessary variables are given
    missing_variables = [va for va in ["thetao", "so", 'o2'] if va not in ds.variables]
    if len(missing_variables)>0:
        flag = True
        problems['missing_variables'].append((name, missing_variables))
        
    # Check for area
    if not 'areacello' in ds.coords:
        if ds.attrs['grid_label'] == 'gr': # only reconstruct for regular grids
            grid, ds = combine_staggered_grid(ds, recalculate_metrics=True)
            # I am dropping dz_t here so it can be uniformly reconstructed
            ds = ds.drop('dz_t')
            ds = ds.assign_coords(areacello = (ds.dx_t * ds.dy_t).reset_coords(drop=True))
            problems['reconstructed_area'].append(name)
            assert 'areacello' in ds.coords
        else:
            flag = True
            problems['missing_area'].append(name)
    
    # Check for thickness (and rename) TODO: We should probably not rename and just refactor to use `thkcello`
    if "thkcello" in ds.coords:
        ds = ds.rename({'thkcello': 'dz_t'})
    else:
        # try to reconstruct the thickness from static info
        try:
#             lev_vertices = cf_xarray.bounds_to_vertices(ds.lev_bounds, 'bnds').load()
#             dz_t = lev_vertices.diff('lev_vertices')
#             ds = ds.assign_coords(dz_t=('lev', dz_t.data))
            ds = construct_static_dz(ds).rename({'thkcello': 'dz_t'})
            problems['reconstructed_thickness'].append(name)
        except Exception as e:
            print(f'{name} thickness reconstruction failed with {e}')
            print(ds)
            problems['missing_thickness'].append(name)
            flag=True
            
    if not flag:
        ddict_filtered[name] = ds
problems
# Out:
# {'missing_variables': [('ACCESS-ESM1-5.gn.Omon.r10i1p1f1', ['thetao']),
#   ('IPSL-CM6A-LR.gn.Omon.r3i1p1f1', ['o2'])],
#  'missing_area': [],
#  'missing_thickness': [],
#  'reconstructed_area': [],
#  'reconstructed_thickness': ['ACCESS-ESM1-5.gn.Omon.r1i1p1f1',
#   'ACCESS-ESM1-5.gn.Omon.r9i1p1f1',
#   'ACCESS-ESM1-5.gn.Omon.r8i1p1f1',
#   'ACCESS-ESM1-5.gn.Omon.r5i1p1f1',
#   'ACCESS-ESM1-5.gn.Omon.r2i1p1f1',
#   'ACCESS-ESM1-5.gn.Omon.r4i1p1f1',
#   'MIROC-ES2L.gn.Omon.r2i1p1f2',
#   'MIROC-ES2L.gn.Omon.r7i1p1f2',
#   'MIROC-ES2L.gn.Omon.r4i1p1f2',
#   'MIROC-ES2L.gn.Omon.r10i1p1f2',
#   'MIROC-ES2L.gn.Omon.r3i1p1f2',
#   'MIROC-ES2L.gn.Omon.r1i1p1f2',
#   'MIROC-ES2L.gn.Omon.r6i1p1f2',
#   'MIROC-ES2L.gn.Omon.r9i1p1f2',
#   'MIROC-ES2L.gn.Omon.r5i1p1f2',
#   'MIROC-ES2L.gn.Omon.r8i1p1f2']}

# %%
list(o2_models())
# Out:
# ['ACCESS-ESM1-5',
#  'CESM2',
#  'CESM2-WACCM',
#  'CMCC-ESM2',
#  'CNRM-ESM2-1',
#  'CanESM5',
#  'CanESM5-CanOE',
#  'EC-Earth3-CC',
#  'GFDL-CM4',
#  'GFDL-ESM4',
#  'IPSL-CM5A2-INCA',
#  'IPSL-CM6A-LR',
#  'KIOST-ESM',
#  'MIROC-ES2L',
#  'MPI-ESM-1-2-HAM',
#  'MPI-ESM1-2-HR',
#  'MPI-ESM1-2-LR',
#  'MRI-ESM2-0',
#  'NorESM2-LM',
#  'NorESM2-MM',
#  'UKESM1-0-LL']

# %%
# ddict_final = pick_first_member(ddict_filtered)#

# # # Final version: Put out all full memmbers
ddict_final = ddict_filtered

list(np.sort(list(ddict_final.keys())))
# Out:
# ['ACCESS-ESM1-5.gn.Omon.r1i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r2i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r4i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r5i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r6i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r8i1p1f1',
#  'ACCESS-ESM1-5.gn.Omon.r9i1p1f1',
#  'CNRM-ESM2-1.gn.Omon.r1i1p1f2',
#  'CNRM-ESM2-1.gn.Omon.r2i1p1f2',
#  'CNRM-ESM2-1.gn.Omon.r3i1p1f2',
#  'CNRM-ESM2-1.gn.Omon.r4i1p1f2',
#  'CNRM-ESM2-1.gn.Omon.r5i1p1f2',
#  'CanESM5-CanOE.gn.Omon.r1i1p2f1',
#  'CanESM5-CanOE.gn.Omon.r2i1p2f1',
#  'CanESM5-CanOE.gn.Omon.r3i1p2f1',
#  'CanESM5.gn.Omon.r10i1p1f1',
#  'CanESM5.gn.Omon.r10i1p2f1',
#  'CanESM5.gn.Omon.r1i1p1f1',
#  'CanESM5.gn.Omon.r1i1p2f1',
#  'CanESM5.gn.Omon.r2i1p1f1',
#  'CanESM5.gn.Omon.r2i1p2f1',
#  'CanESM5.gn.Omon.r3i1p1f1',
#  'CanESM5.gn.Omon.r3i1p2f1',
#  'CanESM5.gn.Omon.r4i1p1f1',
#  'CanESM5.gn.Omon.r4i1p2f1',
#  'CanESM5.gn.Omon.r5i1p1f1',
#  'CanESM5.gn.Omon.r5i1p2f1',
#  'CanESM5.gn.Omon.r6i1p1f1',
#  'CanESM5.gn.Omon.r6i1p2f1',
#  'CanESM5.gn.Omon.r7i1p1f1',
#  'CanESM5.gn.Omon.r7i1p2f1',
#  'CanESM5.gn.Omon.r8i1p1f1',
#  'CanESM5.gn.Omon.r8i1p2f1',
#  'CanESM5.gn.Omon.r9i1p1f1',
#  'CanESM5.gn.Omon.r9i1p2f1',
#  'IPSL-CM6A-LR.gn.Omon.r14i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r1i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r2i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r4i1p1f1',
#  'IPSL-CM6A-LR.gn.Omon.r6i1p1f1',
#  'MIROC-ES2L.gn.Omon.r10i1p1f2',
#  'MIROC-ES2L.gn.Omon.r1i1p1f2',
#  'MIROC-ES2L.gn.Omon.r2i1p1f2',
#  'MIROC-ES2L.gn.Omon.r3i1p1f2',
#  'MIROC-ES2L.gn.Omon.r4i1p1f2',
#  'MIROC-ES2L.gn.Omon.r5i1p1f2',
#  'MIROC-ES2L.gn.Omon.r6i1p1f2',
#  'MIROC-ES2L.gn.Omon.r7i1p1f2',
#  'MIROC-ES2L.gn.Omon.r8i1p1f2',
#  'MIROC-ES2L.gn.Omon.r9i1p1f2',
#  'MPI-ESM1-2-LR.gn.Omon.r10i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r1i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r2i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r3i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r4i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r5i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r6i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r7i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r8i1p1f1',
#  'MPI-ESM1-2-LR.gn.Omon.r9i1p1f1',
#  'UKESM1-0-LL.gn.Omon.r1i1p1f2',
#  'UKESM1-0-LL.gn.Omon.r2i1p1f2',
#  'UKESM1-0-LL.gn.Omon.r3i1p1f2',
#  'UKESM1-0-LL.gn.Omon.r4i1p1f2',
#  'UKESM1-0-LL.gn.Omon.r8i1p1f2']

# %% [markdown]
# ## Quick update for revision: Add O2_sat and aou

# %%
from cmip6_omz.omz_tools import o2sat
def _add_o2sat(ds):
    ds['o2sat'] = o2sat(ds.thetao, ds.so)
    ds['aou'] = ds.o2sat - ds.o2
    return ds

# %%
ddict_final = {k:_add_o2sat(ds) for k,ds in ddict_final.items()}

# %%
overwrite=False
for lev_slice in [slice(100, 3000)]:# , # #slice(100, 2000)slice(200, 1000)
    for name, ds in ddict_final.items():
        print('-----------')
        for var in ['o2sat', 'aou']:# #,'agessc', 'o2'
            print(name)
            if var not in ds.data_vars:
                print(f"{var} is not in the dataset")
            else:
                da = ds[var].sel(lev=lev_slice)
                da = da.weighted(da.dz_t.fillna(0)).mean('lev')
                ds_out = da.to_dataset(name=var)
                ds_out.attrs = {k:v for k,v in ds.attrs.items() if k not in ['intake_esm_varname']}
    #             ds_out.attrs['variable_id'] = var
                ds_out.attrs['depth_range'] = f"{str(lev_slice.start)}-{str(lev_slice.stop)}"
                ds_out = ds_out.coarsen(time=12).mean('time')

                filename = ofolder.joinpath(f"{cmip6_dataset_id(ds_out)}_{lev_slice.start}-{lev_slice.stop}m_{var}.zarr")

                dim_split = 40 if not 'GFDL' in name else 10
                if not zarr_exists(filename) or overwrite:
                    print(filename)
                    append_write_zarr(ds_out, filename, dim_split)
                else:
                    print('exists')
# Out:
# -----------
# IPSL-CM6A-LR.gn.Omon.r1i1p1f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.IPSL.IPSL-CM6A-LR.none.r1i1p1f1.Omon.gn.none.none_100-3000m_o2sat.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 56:37<00:00]
#     </div>
# IPSL-CM6A-LR.gn.Omon.r1i1p1f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.IPSL.IPSL-CM6A-LR.none.r1i1p1f1.Omon.gn.none.none_100-3000m_aou.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 1:23:33<00:00]
#     </div>
# -----------
# CNRM-ESM2-1.gn.Omon.r5i1p1f2
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CNRM-CERFACS.CNRM-ESM2-1.none.r5i1p1f2.Omon.gn.none.none_100-3000m_o2sat.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 19:12<00:00]
#     </div>
# CNRM-ESM2-1.gn.Omon.r5i1p1f2
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CNRM-CERFACS.CNRM-ESM2-1.none.r5i1p1f2.Omon.gn.none.none_100-3000m_aou.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 26:04<00:00]
#     </div>
# -----------
# ACCESS-ESM1-5.gn.Omon.r1i1p1f1
# exists
# ACCESS-ESM1-5.gn.Omon.r1i1p1f1
# exists
# -----------
# ACCESS-ESM1-5.gn.Omon.r6i1p1f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CSIRO.ACCESS-ESM1-5.none.r6i1p1f1.Omon.gn.none.none_100-3000m_o2sat.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 17:37<00:00]
#     </div>
# ACCESS-ESM1-5.gn.Omon.r6i1p1f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CSIRO.ACCESS-ESM1-5.none.r6i1p1f1.Omon.gn.none.none_100-3000m_aou.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 26:30<00:00]
#     </div>
# -----------
# CanESM5.gn.Omon.r3i1p1f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CCCma.CanESM5.none.r3i1p1f1.Omon.gn.v20190429.none_100-3000m_o2sat.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 10:00<00:00]
#     </div>
# CanESM5.gn.Omon.r3i1p1f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CCCma.CanESM5.none.r3i1p1f1.Omon.gn.v20190429.none_100-3000m_aou.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 15:04<00:00]
#     </div>
# -----------
# ACCESS-ESM1-5.gn.Omon.r9i1p1f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CSIRO.ACCESS-ESM1-5.none.r9i1p1f1.Omon.gn.none.none_100-3000m_o2sat.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 15:06<00:00]
#     </div>
# ACCESS-ESM1-5.gn.Omon.r9i1p1f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CSIRO.ACCESS-ESM1-5.none.r9i1p1f1.Omon.gn.none.none_100-3000m_aou.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 25:47<00:00]
#     </div>
# -----------
# CanESM5-CanOE.gn.Omon.r3i1p2f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CCCma.CanESM5-CanOE.none.r3i1p2f1.Omon.gn.v20190429.none_100-3000m_o2sat.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 11:05<00:00]
#     </div>
# CanESM5-CanOE.gn.Omon.r3i1p2f1
# /projects/GEOCLIM/LRGROUP/jbusecke/projects_data/cmip6_depth_average_v0.3/none.CCCma.CanESM5-CanOE.none.r3i1p2f1.Omon.gn.v20190429.none_100-3000m_aou.zarr
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [4/6 13:22<06:41]
#     </div>
